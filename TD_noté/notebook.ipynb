# %% [markdown]
# ### 1) Importations

# %%
import utils
import numpy as np
import pandas as pd

print(utils.__file__)
print(dir(utils))
# Out:
# C:\Users\Baptiste\OneDrive - Efrei\Bureau\Baptiste\Efrei\I1\S6 - efrei\ml\Mastercamp\TD_noté\utils.py
# ['OneHotEncoder', 'TfidfVectorizer', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'complete_cvss_missing_values', 'complete_epss_missing_values', 'create_completed_dataset', 'create_cvss_train_test_data', 'create_epss_train_test_data', 'create_risk_score', 'evaluate_model', 'get_cvss_columns', 'load_prepare_and_encode_dataset', 'mean_absolute_error', 'mean_squared_error', 'np', 'pd', 'process_new_data', 'r2_score']

# %%
from sklearn.ensemble import GradientBoostingRegressor

from utils import (
    load_prepare_and_encode_dataset,
    get_cvss_columns,
    create_cvss_train_test_data,
    evaluate_model,
    complete_cvss_missing_values,
    create_epss_train_test_data,
    complete_epss_missing_values,
    create_completed_dataset,
    process_new_data
)

# %% [markdown]
# ### 2) Chargement et encodage du dataset

# %%
df, dataset_encoded, OneHot_encoder, TfIdf_vectorizer = load_prepare_and_encode_dataset("./data/test.csv")

# %%
print("Shape :", dataset_encoded.shape)

print("Valeurs manquantes restantes :")
print(dataset_encoded.isna().sum().sort_values(ascending=False).head(10))

df.head()
# Out:
# Shape : (125372, 7749)
# Valeurs manquantes restantes :
# CVSS                                                                    96091
# EPSS                                                                      763
# Type_Alerte                                                                 0
# Type_Avis                                                                   0
# Editeur_ AMD, AMD, AMD, AMD, AMD, AMD , AMD, AMD, AMD, AMD, AMD, AMD        0
# tfidf_warning                                                               0
# Editeur_ADOdb                                                               0
# Editeur_AMD                                                                 0
# Editeur_AMD,  AMD                                                           0
# Editeur_AMD, AMD                                                            0
# dtype: int64
#               ID ANSSI                                        Titre ANSSI  \
# 0  CERTFR-2021-ALE-001          |MàJ] Vulnérabilité dans SonicWall SMA100
# 1  CERTFR-2021-ALE-001          |MàJ] Vulnérabilité dans SonicWall SMA100
# 2  CERTFR-2021-ALE-002  [MàJ] Vulnérabilité dans Google Chrome et Micr...
# 3  CERTFR-2021-ALE-003     [MàJ] Vulnérabilité dans VMware vCenter Server
# 4  CERTFR-2021-ALE-004  [MàJ] Multiples vulnérabilités dans Microsoft ...
#
#      Type       Date             CVE  \
# 0  Alerte 2021-02-02  CVE-2021-20016
# 1  Alerte 2021-02-02   CVE-2014-6271
# 2  Alerte 2021-02-05  CVE-2021-21148
# 3  Alerte 2021-02-25  CVE-2021-21972
# 4  Alerte 2021-03-03  CVE-2021-26858
#
#                                          Description  CVSS Base Severity  \
# 0  A SQL-Injection vulnerability in the SonicWall...   NaN       Unknown
# 1  GNU Bash through 4.3 processes trailing string...   NaN       Unknown
# 2  Heap buffer overflow in V8 in Google Chrome pr...   NaN       Unknown
# 3  The vSphere Client (HTML5) contains a remote c...   NaN       Unknown
# 4  Microsoft Exchange Server Remote Code Executio...   7.8          HIGH
#
#   Attack Vector Attack Complexity  ...  \
# 0       Unknown           Unknown  ...
# 1       Unknown           Unknown  ...
# 2       Unknown           Unknown  ...
# 3       Unknown           Unknown  ...
# 4         LOCAL               LOW  ...
#
#                                        Lien solution  \
# 0  https://psirt.global.sonicwall.com/vuln-detail...
# 1  http://lists.opensuse.org/opensuse-security-an...
# 2  https://lists.fedoraproject.org/archives/list/...
# 3  https://www.vmware.com/security/advisories/VMS...
# 4  https://portal.msrc.microsoft.com/en-US/securi...
#
#                                      Description CWE  \
# 0  CWE-89: Improper Neutralization of Special Ele...
# 1
# 2                               Heap buffer overflow
# 3                Remote code execution vulnerability
# 4                              Remote Code Execution
#
#                                              Editeur  \
# 0                                          SonicWall
# 1                                            Unknown
# 2                                             Google
# 3                                           n/a, n/a
# 4  Microsoft, Microsoft, Microsoft, Microsoft, Mi...
#
#                                              Produit  \
# 0                                   SonicWall SMA100
# 1                                            Unknown
# 2                                             Chrome
# 3    VMware vCenter Server,  VMware Cloud Foundation
# 4  Microsoft Exchange Server 2019,  Microsoft Exc...
#
#                                   Versions affectées  year  month  \
# 0                          SMA100 build version 10.x  2021      2
# 1                                                NaN  2021      2
# 2                                        unspecified  2021      2
# 3  7.x before 7.0 U1c, 6.7 before 6.7 U3l, 6.5 be...  2021      2
# 4  15.02.0, 15.00.0, 15.02.0, 15.01.0, 15.00.0, 1...  2021      3
#
#   EPSS_missing EPSS_filled                                     text_for_tfidf
# 0            0     0.79818  |MàJ] Vulnérabilité dans SonicWall SMA100 A SQ...
# 1            0     0.94220  |MàJ] Vulnérabilité dans SonicWall SMA100 GNU ...
# 2            0     0.19904  [MàJ] Vulnérabilité dans Google Chrome et Micr...
# 3            0     0.93821  [MàJ] Vulnérabilité dans VMware vCenter Server...
# 4            0     0.55064  [MàJ] Multiples vulnérabilités dans Microsoft ...
#
# [5 rows x 28 columns]

# %% [markdown]
# ### 3) Creation des test/split set pour modele CVSS

# %%
cols_to_remove = get_cvss_columns(dataset_encoded)
print("Nombre de colonnes retirées :", len(cols_to_remove))
# Out:
# Nombre de colonnes retirées : 35

# %%
X_train_realistic, X_test_realistic, y_train_realistic, y_test_realistic = create_cvss_train_test_data(
    dataset_encoded,
    cols_to_remove
)

# %%
print(X_train_realistic.shape)
print(X_test_realistic.shape)
print(y_train_realistic.shape)
print(y_test_realistic.shape)

print("NaN dans X_train :", X_train_realistic.isna().sum().sum())
# Out:
# (23424, 7712)
# (5857, 7712)
# (23424,)
# (5857,)
# NaN dans X_train : 0

# %% [markdown]
# ### 4) Entrainement du meilleur modele cvss

# %%
model_cvss_realistic = GradientBoostingRegressor(
    random_state=42,
    subsample=1.0,
    n_estimators=150,
    min_samples_leaf=10,
    max_depth=4,
    learning_rate=0.1
)

model_cvss_realistic.fit(X_train_realistic, y_train_realistic)
# Out:
# GradientBoostingRegressor(max_depth=4, min_samples_leaf=10, n_estimators=150,
#                           random_state=42)

# %% [markdown]
# ### 5) Evaluation du modele

# %%
y_pred_realistic = model_cvss_realistic.predict(X_test_realistic)

evaluate_model(y_test_realistic, y_pred_realistic)
# Out:
# MAE : 0.8642822480152852
# RMSE : 1.1687532135490328
# R² : 0.5240206729102144
# (0.8642822480152852, np.float64(1.1687532135490328), 0.5240206729102144)

# %%
y_pred_train = model_cvss_realistic.predict(X_train_realistic)

print("Performances sur le train :")
evaluate_model(y_train_realistic, y_pred_train)

print("Performances sur le test :")
evaluate_model(y_test_realistic, y_pred_realistic)
# Out:
# Performances sur le train :
# MAE : 0.8369223021677061
# RMSE : 1.1266069961311955
# R² : 0.5567154931233649
# Performances sur le test :
# MAE : 0.8642822480152852
# RMSE : 1.1687532135490328
# R² : 0.5240206729102144
# (0.8642822480152852, np.float64(1.1687532135490328), 0.5240206729102144)

# %% [markdown]
# Le modele ne semble pas overfitter

# %% [markdown]
# ### 6) Completion cvss manquants

# %%
df = complete_cvss_missing_values(
    df,
    dataset_encoded,
    model_cvss_realistic,
    cols_to_remove
)

# %% [markdown]
# ### 7) Sauvegarde des resultats

# %%
df.to_csv("./data/dataset_with_cvss_completed.csv", sep=";", index=False)

# %% [markdown]
# # B) Prediction des EPSS manquants

# %% [markdown]
# ### 1) Creation des test/split set pour modele EPSS

# %%
X_train_epss, X_test_epss, y_train_epss, y_test_epss = create_epss_train_test_data(
    dataset_encoded,
    df
)

print(X_train_epss.shape)
print(X_test_epss.shape)
print(y_train_epss.shape)
print(y_test_epss.shape)

print("NaN dans X_train_epss :", X_train_epss.isna().sum().sum())
# Out:
# (99687, 7746)
# (24922, 7746)
# (99687,)
# (24922,)
# NaN dans X_train_epss : 0

# %% [markdown]
# ### 2) Entrainement du modele EPSS

# %%
model_epss = GradientBoostingRegressor(
    random_state=42,
    n_estimators=100,
    learning_rate=0.05,
    max_depth=3,
    min_samples_leaf=5,
    subsample=1.0
)

model_epss.fit(X_train_epss, y_train_epss)
# Out:
# GradientBoostingRegressor(learning_rate=0.05, min_samples_leaf=5,
#                           random_state=42)

# %%
y_pred_epss = model_epss.predict(X_test_epss)

evaluate_model(y_test_epss, y_pred_epss)
# Out:
# MAE : 0.016820565317123184
# RMSE : 0.0686177656523449
# R² : 0.3737621866456955
# (0.016820565317123184, np.float64(0.0686177656523449), 0.3737621866456955)

# %%
df = complete_epss_missing_values(
    df,
    dataset_encoded,
    model_epss
)

# %%
print("EPSS manquants avant :", df["EPSS"].isna().sum())
print("EPSS_completed manquants après :", df["EPSS_completed"].isna().sum())

df[["CVE", "CVSS", "CVSS_completed", "EPSS", "EPSS_completed"]].head(20)
# Out:
# EPSS manquants avant : 763
# EPSS_completed manquants après : 0
#                CVE  CVSS  CVSS_completed     EPSS  EPSS_completed
# 0   CVE-2021-20016   NaN        7.880039  0.79818         0.79818
# 1    CVE-2014-6271   NaN        9.183692  0.94220         0.94220
# 2   CVE-2021-21148   NaN        7.646241  0.19904         0.19904
# 3   CVE-2021-21972   NaN        8.858985  0.93821         0.93821
# 4   CVE-2021-26858   7.8        7.800000  0.55064         0.55064
# 5   CVE-2021-27078   9.1        9.100000  0.32551         0.32551
# 6   CVE-2021-26857   7.8        7.800000  0.34542         0.34542
# 7   CVE-2021-26855   9.1        9.100000  0.94351         0.94351
# 8   CVE-2021-27065   7.8        7.800000  0.94282         0.94282
# 9   CVE-2021-26412   9.1        9.100000  0.24204         0.24204
# 10  CVE-2021-26854   6.6        6.600000  0.05151         0.05151
# 11  CVE-2021-26893   9.8        9.800000  0.08310         0.08310
# 12  CVE-2021-26897   9.8        9.800000  0.10984         0.10984
# 13  CVE-2021-26894   9.8        9.800000  0.09935         0.09935
# 14  CVE-2021-26877   9.8        9.800000  0.09227         0.09227
# 15  CVE-2021-26895   9.8        9.800000  0.09935         0.09935
# 16  CVE-2021-22986   NaN        9.005125  0.94485         0.94485
# 17  CVE-2021-22893   NaN        9.631303  0.93378         0.93378
# 18  CVE-2021-22894   NaN        8.697759  0.50620         0.50620
# 19  CVE-2021-22899   NaN        8.410315  0.37999         0.37999

# %%
df.to_csv("./data/dataset_with_cvss_and_epss_completed.csv", sep=";", index=False)

# %% [markdown]
# ### C) Creation du score de risque

# %%
df_completed = create_completed_dataset(df)

# %%
df_completed[[
    "CVE",
    "CVSS",
    "CVSS_completed",
    "EPSS",
    "EPSS_completed",
    "risk_score",
    "risk_priority"
]].head(20)
# Out:
#                CVE  CVSS  CVSS_completed     EPSS  EPSS_completed  risk_score  \
# 0   CVE-2021-20016   NaN        7.880039  0.79818         0.79818    0.792074
# 1    CVE-2014-6271   NaN        9.183692  0.94220         0.94220    0.927902
# 2   CVE-2021-21148   NaN        7.646241  0.19904         0.19904    0.538390
# 3   CVE-2021-21972   NaN        8.858985  0.93821         0.93821    0.906823
# 4   CVE-2021-26858   7.8        7.800000  0.55064         0.55064    0.688256
# 5   CVE-2021-27078   9.1        9.100000  0.32551         0.32551    0.676204
# 6   CVE-2021-26857   7.8        7.800000  0.34542         0.34542    0.606168
# 7   CVE-2021-26855   9.1        9.100000  0.94351         0.94351    0.923404
# 8   CVE-2021-27065   7.8        7.800000  0.94282         0.94282    0.845128
# 9   CVE-2021-26412   9.1        9.100000  0.24204         0.24204    0.642816
# 10  CVE-2021-26854   6.6        6.600000  0.05151         0.05151    0.416604
# 11  CVE-2021-26893   9.8        9.800000  0.08310         0.08310    0.621240
# 12  CVE-2021-26897   9.8        9.800000  0.10984         0.10984    0.631936
# 13  CVE-2021-26894   9.8        9.800000  0.09935         0.09935    0.627740
# 14  CVE-2021-26877   9.8        9.800000  0.09227         0.09227    0.624908
# 15  CVE-2021-26895   9.8        9.800000  0.09935         0.09935    0.627740
# 16  CVE-2021-22986   NaN        9.005125  0.94485         0.94485    0.918247
# 17  CVE-2021-22893   NaN        9.631303  0.93378         0.93378    0.951390
# 18  CVE-2021-22894   NaN        8.697759  0.50620         0.50620    0.724346
# 19  CVE-2021-22899   NaN        8.410315  0.37999         0.37999    0.656615
#
#    risk_priority
# 0           HIGH
# 1       CRITICAL
# 2         MEDIUM
# 3       CRITICAL
# 4           HIGH
# 5           HIGH
# 6           HIGH
# 7       CRITICAL
# 8       CRITICAL
# 9           HIGH
# 10        MEDIUM
# 11          HIGH
# 12          HIGH
# 13          HIGH
# 14          HIGH
# 15          HIGH
# 16      CRITICAL
# 17      CRITICAL
# 18          HIGH
# 19          HIGH

# %%
df_completed["risk_priority"].value_counts()
# Out:
# risk_priority
# MEDIUM      117998
# LOW           5593
# HIGH          1049
# CRITICAL       732
# Name: count, dtype: int64

# %%
df_completed.groupby("risk_priority")[[
    "CVSS_completed",
    "EPSS_completed",
    "risk_score"
]].mean()
# Out:
# C:\Users\Baptiste\AppData\Local\Temp\ipykernel_27068\4232588133.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_completed.groupby("risk_priority")[[
#                CVSS_completed  EPSS_completed  risk_score
# risk_priority
# LOW                  3.975023        0.002355    0.239443
# MEDIUM               7.378790        0.004120    0.444375
# HIGH                 8.343468        0.435574    0.674838
# CRITICAL             8.396338        0.895878    0.862132

# %% [markdown]
# # D) Sauvegarde du dataset final enrichi

# %%
df_completed.to_csv("./data/dataset_completed_final.csv", sep=";", index=False)

# %%
df_completed.head(20)
# Out:
#                ID ANSSI                                        Titre ANSSI  \
# 0   CERTFR-2021-ALE-001          |MàJ] Vulnérabilité dans SonicWall SMA100
# 1   CERTFR-2021-ALE-001          |MàJ] Vulnérabilité dans SonicWall SMA100
# 2   CERTFR-2021-ALE-002  [MàJ] Vulnérabilité dans Google Chrome et Micr...
# 3   CERTFR-2021-ALE-003     [MàJ] Vulnérabilité dans VMware vCenter Server
# 4   CERTFR-2021-ALE-004  [MàJ] Multiples vulnérabilités dans Microsoft ...
# 5   CERTFR-2021-ALE-004  [MàJ] Multiples vulnérabilités dans Microsoft ...
# 6   CERTFR-2021-ALE-004  [MàJ] Multiples vulnérabilités dans Microsoft ...
# 7   CERTFR-2021-ALE-004  [MàJ] Multiples vulnérabilités dans Microsoft ...
# 8   CERTFR-2021-ALE-004  [MàJ] Multiples vulnérabilités dans Microsoft ...
# 9   CERTFR-2021-ALE-004  [MàJ] Multiples vulnérabilités dans Microsoft ...
# 10  CERTFR-2021-ALE-004  [MàJ] Multiples vulnérabilités dans Microsoft ...
# 11  CERTFR-2021-ALE-005  Multiples vulnérabilités dans Microsoft DNS se...
# 12  CERTFR-2021-ALE-005  Multiples vulnérabilités dans Microsoft DNS se...
# 13  CERTFR-2021-ALE-005  Multiples vulnérabilités dans Microsoft DNS se...
# 14  CERTFR-2021-ALE-005  Multiples vulnérabilités dans Microsoft DNS se...
# 15  CERTFR-2021-ALE-005  Multiples vulnérabilités dans Microsoft DNS se...
# 16  CERTFR-2021-ALE-006                 [MàJ] Vulnérabilité dans F5 BIG-IP
# 17  CERTFR-2021-ALE-007      [MàJ] Vulnérabilité dans Pulse Connect Secure
# 18  CERTFR-2021-ALE-007      [MàJ] Vulnérabilité dans Pulse Connect Secure
# 19  CERTFR-2021-ALE-007      [MàJ] Vulnérabilité dans Pulse Connect Secure
#
#       Type       Date             CVE  \
# 0   Alerte 2021-02-02  CVE-2021-20016
# 1   Alerte 2021-02-02   CVE-2014-6271
# 2   Alerte 2021-02-05  CVE-2021-21148
# 3   Alerte 2021-02-25  CVE-2021-21972
# 4   Alerte 2021-03-03  CVE-2021-26858
# 5   Alerte 2021-03-03  CVE-2021-27078
# 6   Alerte 2021-03-03  CVE-2021-26857
# 7   Alerte 2021-03-03  CVE-2021-26855
# 8   Alerte 2021-03-03  CVE-2021-27065
# 9   Alerte 2021-03-03  CVE-2021-26412
# 10  Alerte 2021-03-03  CVE-2021-26854
# 11  Alerte 2021-03-12  CVE-2021-26893
# 12  Alerte 2021-03-12  CVE-2021-26897
# 13  Alerte 2021-03-12  CVE-2021-26894
# 14  Alerte 2021-03-12  CVE-2021-26877
# 15  Alerte 2021-03-12  CVE-2021-26895
# 16  Alerte 2021-03-22  CVE-2021-22986
# 17  Alerte 2021-04-20  CVE-2021-22893
# 18  Alerte 2021-04-20  CVE-2021-22894
# 19  Alerte 2021-04-20  CVE-2021-22899
#
#                                           Description  CVSS Base Severity  \
# 0   A SQL-Injection vulnerability in the SonicWall...   NaN       Unknown
# 1   GNU Bash through 4.3 processes trailing string...   NaN       Unknown
# 2   Heap buffer overflow in V8 in Google Chrome pr...   NaN       Unknown
# 3   The vSphere Client (HTML5) contains a remote c...   NaN       Unknown
# 4   Microsoft Exchange Server Remote Code Executio...   7.8          HIGH
# 5   Microsoft Exchange Server Remote Code Executio...   9.1      CRITICAL
# 6   Microsoft Exchange Server Remote Code Executio...   7.8          HIGH
# 7   Microsoft Exchange Server Remote Code Executio...   9.1      CRITICAL
# 8   Microsoft Exchange Server Remote Code Executio...   7.8          HIGH
# 9   Microsoft Exchange Server Remote Code Executio...   9.1      CRITICAL
# 10  Microsoft Exchange Server Remote Code Executio...   6.6        MEDIUM
# 11  Windows DNS Server Remote Code Execution Vulne...   9.8      CRITICAL
# 12  Windows DNS Server Remote Code Execution Vulne...   9.8      CRITICAL
# 13  Windows DNS Server Remote Code Execution Vulne...   9.8      CRITICAL
# 14  Windows DNS Server Remote Code Execution Vulne...   9.8      CRITICAL
# 15  Windows DNS Server Remote Code Execution Vulne...   9.8      CRITICAL
# 16  On BIG-IP versions 16.0.x before 16.0.1.1, 15....   NaN       Unknown
# 17  Pulse Connect Secure 9.0R3/9.1R1 and higher is...   NaN       Unknown
# 18  A buffer overflow vulnerability exists in Puls...   NaN       Unknown
# 19  A command injection vulnerability exists in Pu...   NaN       Unknown
#
#    Attack Vector Attack Complexity  ...  \
# 0        Unknown           Unknown  ...
# 1        Unknown           Unknown  ...
# 2        Unknown           Unknown  ...
# 3        Unknown           Unknown  ...
# 4          LOCAL               LOW  ...
# 5        NETWORK               LOW  ...
# 6          LOCAL               LOW  ...
# 7        NETWORK               LOW  ...
# 8          LOCAL               LOW  ...
# 9        NETWORK               LOW  ...
# 10       NETWORK              HIGH  ...
# 11       NETWORK               LOW  ...
# 12       NETWORK               LOW  ...
# 13       NETWORK               LOW  ...
# 14       NETWORK               LOW  ...
# 15       NETWORK               LOW  ...
# 16       Unknown           Unknown  ...
# 17       Unknown           Unknown  ...
# 18       Unknown           Unknown  ...
# 19       Unknown           Unknown  ...
#
#                                    Versions affectées  year month  \
# 0                           SMA100 build version 10.x  2021     2
# 1                                                 NaN  2021     2
# 2                                         unspecified  2021     2
# 3   7.x before 7.0 U1c, 6.7 before 6.7 U3l, 6.5 be...  2021     2
# 4   15.02.0, 15.00.0, 15.02.0, 15.01.0, 15.00.0, 1...  2021     3
# 5         15.01.0, 15.02.0, 15.00.0, 15.02.0, 15.01.0  2021     3
# 6   15.01.0, 15.02.0, 15.02.0, 15.00.0, 15.02.0, 1...  2021     3
# 7   15.01.0, 15.02.0, 15.02.0, 15.00.0, 15.02.0, 1...  2021     3
# 8   15.02.0, 15.00.0, 15.02.0, 15.01.0, 15.00.0, 1...  2021     3
# 9         15.00.0, 15.02.0, 15.01.0, 15.01.0, 15.02.0  2021     3
# 10        15.01.0, 15.02.0, 15.00.0, 15.02.0, 15.01.0  2021     3
# 11  10.0.0, 10.0.0, 10.0.0, 10.0.0, 10.0.0, 10.0.0...  2021     3
# 12  10.0.0, 10.0.0, 10.0.0, 10.0.0, 10.0.0, 10.0.0...  2021     3
# 13  10.0.0, 10.0.0, 10.0.0, 10.0.0, 10.0.0, 10.0.0...  2021     3
# 14  10.0.0, 10.0.0, 10.0.0, 10.0.0, 10.0.0, 10.0.0...  2021     3
# 15  10.0.0, 10.0.0, 10.0.0, 10.0.0, 10.0.0, 10.0.0...  2021     3
# 16  BIG-IP 16.0.x before 16.0.1.1, 15.1.x before 1...  2021     3
# 17            PCS 9.0R3 or above, PCS 9.1R1 and above  2021     4
# 18                             Fixed version 9.1R11.4  2021     4
# 19                                  Fixed in 9.1R11.4  2021     4
#
#    EPSS_missing EPSS_filled  \
# 0             0     0.79818
# 1             0     0.94220
# 2             0     0.19904
# 3             0     0.93821
# 4             0     0.55064
# 5             0     0.32551
# 6             0     0.34542
# 7             0     0.94351
# 8             0     0.94282
# 9             0     0.24204
# 10            0     0.05151
# 11            0     0.08310
# 12            0     0.10984
# 13            0     0.09935
# 14            0     0.09227
# 15            0     0.09935
# 16            0     0.94485
# 17            0     0.93378
# 18            0     0.50620
# 19            0     0.37999
#
#                                        text_for_tfidf  CVSS_completed  \
# 0   |MàJ] Vulnérabilité dans SonicWall SMA100 A SQ...        7.880039
# 1   |MàJ] Vulnérabilité dans SonicWall SMA100 GNU ...        9.183692
# 2   [MàJ] Vulnérabilité dans Google Chrome et Micr...        7.646241
# 3   [MàJ] Vulnérabilité dans VMware vCenter Server...        8.858985
# 4   [MàJ] Multiples vulnérabilités dans Microsoft ...        7.800000
# 5   [MàJ] Multiples vulnérabilités dans Microsoft ...        9.100000
# 6   [MàJ] Multiples vulnérabilités dans Microsoft ...        7.800000
# 7   [MàJ] Multiples vulnérabilités dans Microsoft ...        9.100000
# 8   [MàJ] Multiples vulnérabilités dans Microsoft ...        7.800000
# 9   [MàJ] Multiples vulnérabilités dans Microsoft ...        9.100000
# 10  [MàJ] Multiples vulnérabilités dans Microsoft ...        6.600000
# 11  Multiples vulnérabilités dans Microsoft DNS se...        9.800000
# 12  Multiples vulnérabilités dans Microsoft DNS se...        9.800000
# 13  Multiples vulnérabilités dans Microsoft DNS se...        9.800000
# 14  Multiples vulnérabilités dans Microsoft DNS se...        9.800000
# 15  Multiples vulnérabilités dans Microsoft DNS se...        9.800000
# 16  [MàJ] Vulnérabilité dans F5 BIG-IP On BIG-IP v...        9.005125
# 17  [MàJ] Vulnérabilité dans Pulse Connect Secure ...        9.631303
# 18  [MàJ] Vulnérabilité dans Pulse Connect Secure ...        8.697759
# 19  [MàJ] Vulnérabilité dans Pulse Connect Secure ...        8.410315
#
#    EPSS_completed risk_score risk_priority
# 0         0.79818   0.792074          HIGH
# 1         0.94220   0.927902      CRITICAL
# 2         0.19904   0.538390        MEDIUM
# 3         0.93821   0.906823      CRITICAL
# 4         0.55064   0.688256          HIGH
# 5         0.32551   0.676204          HIGH
# 6         0.34542   0.606168          HIGH
# 7         0.94351   0.923404      CRITICAL
# 8         0.94282   0.845128      CRITICAL
# 9         0.24204   0.642816          HIGH
# 10        0.05151   0.416604        MEDIUM
# 11        0.08310   0.621240          HIGH
# 12        0.10984   0.631936          HIGH
# 13        0.09935   0.627740          HIGH
# 14        0.09227   0.624908          HIGH
# 15        0.09935   0.627740          HIGH
# 16        0.94485   0.918247      CRITICAL
# 17        0.93378   0.951390      CRITICAL
# 18        0.50620   0.724346          HIGH
# 19        0.37999   0.656615          HIGH
#
# [20 rows x 32 columns]

# %% [markdown]
# # E) Sauvegarde des modèles et encodeurs

# %%
import joblib
import os

os.makedirs("./models", exist_ok=True)

joblib.dump(OneHot_encoder, "./models/OneHot_encoder.pkl")
joblib.dump(TfIdf_vectorizer, "./models/TfIdf_vectorizer.pkl")

joblib.dump(model_cvss_realistic, "./models/model_cvss_realistic.pkl")
joblib.dump(model_epss, "./models/model_epss.pkl")

joblib.dump(list(X_train_realistic.columns), "./models/cvss_model_columns.pkl")
joblib.dump(list(X_train_epss.columns), "./models/epss_model_columns.pkl")
# Out:
# ['./models/epss_model_columns.pkl']

# %% [markdown]
# # F) Visualisation des priorités

# %%
import matplotlib.pyplot as plt

df_completed["risk_priority"].value_counts().plot(kind="bar")

plt.title("Répartition des vulnérabilités par niveau de priorité")
plt.xlabel("Priorité")
plt.ylabel("Nombre de vulnérabilités")
plt.show()
